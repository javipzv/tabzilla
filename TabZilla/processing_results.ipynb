# %%
import pandas as pd
import numpy as np
import re

# %%
results = pd.read_csv('results.csv')
results_22_05 = pd.read_csv('results_22-05.csv')
results_tan = pd.read_csv('results_tan.csv')
metafeatures = pd.read_csv('metafeatures.csv')

# %% [markdown]
# ## Datasets

# %%
datasets = ['openml__credit-g__31', 'openml__electricity__219',
    'openml__elevators__3711', 'openml__MiniBooNE__168335',
    'openml__guillermo__168337', 'openml__higgs__146606',
    'openml__nomao__9977', 'openml__profb__3561', 'openml__socmob__3797',
    'openml__Australian__146818', 'openml__Bioresponse__9910', 'openml__SpeedDating__146607',
    'openml__ada_agnostic__3896', 'openml__airlines__189354', 'openml__colic__25',
    'openml__colic__27', 'openml__credit-approval__29', 'openml__heart-h__50',
    'openml__jasmine__168911', 'openml__kc1__3917', 'openml__phoneme__9952', 'openml__qsar-biodeg__9957'
]

# %%
meta_cols = ['dataset_name', 'f__pymfe.landmarking.best_node.mean', 'f__pymfe.landmarking.best_node.sd',
             'f__pymfe.landmarking.best_node.max', 'f__pymfe.landmarking.best_node.skewness', 'f__pymfe.landmarking.best_node.kurtosis',
             'f__pymfe.landmarking.best_node.iq_range'] 

metafeatures = metafeatures[meta_cols]

# %%
metafeatures['dataset_name'] = metafeatures['dataset_name'].apply(lambda x: re.sub(r'(__fold.*)', '', x))

# %%
metafeatures_filtered = metafeatures[metafeatures['dataset_name'].isin(datasets)]

# %%
metafeatures_grouped = metafeatures_filtered.groupby('dataset_name').mean()
metafeatures_grouped = metafeatures_grouped.reset_index()

# %%
metafeatures_grouped = metafeatures_grouped[metafeatures_grouped['dataset_name'] != 'openml__colic__27']

# %%
metafeatures_grouped['dataset_name'] = metafeatures_grouped['dataset_name'].apply(lambda x: re.sub(r'openml__', '', x))
metafeatures_grouped['dataset_name'] = metafeatures_grouped['dataset_name'].apply(lambda x: re.sub(r'__.*', '', x))

# %%
metafeatures_grouped.rename(columns={
    'f__pymfe.landmarking.best_node.mean': 'best_node_mean',
    'f__pymfe.landmarking.best_node.sd': 'best_node_std',
    'f__pymfe.landmarking.best_node.max': 'best_node_max',
    'f__pymfe.landmarking.best_node.skewness': 'best_node_skew',
    'f__pymfe.landmarking.best_node.kurtosis': 'best_node_kurt',
    'f__pymfe.landmarking.best_node.iq_range': 'best_node_iq_range'
}, inplace=True)

# %%
def get_n_instances_and_n_features(dataset_name):
    dataset = results[results['dataset_name'] == dataset_name]
    try:
        n_instances = dataset['dataset_num_instances'].values[0]
        n_features = dataset['dataset_num_features'].values[0]
        return n_instances, n_features
    except Exception as e:
        return None, None

# %%
metafeatures_grouped[['num_instances', 'num_features']] = metafeatures_grouped['dataset_name'].apply(
    lambda x: pd.Series(get_n_instances_and_n_features(x))
)

# %%
cols_order = ['dataset_name', 'num_instances', 'num_features', 'best_node_skew',
              'best_node_kurt', 'best_node_iq_range', 'best_node_mean',
              'best_node_std', 'best_node_max']
metafeatures_grouped = metafeatures_grouped[cols_order]

# %%
metafeatures_grouped = metafeatures_grouped[metafeatures_grouped['num_instances'].notna()]\
    .reset_index(drop=True)\
    .sort_values(
        by='dataset_name',
        key=lambda col: col.str.lower()
)

# %%
metafeatures_grouped['num_instances'] = metafeatures_grouped['num_instances'].astype(int)
metafeatures_grouped['num_features'] = metafeatures_grouped['num_features'].astype(int)

# %%
metafeatures_grouped
# Out:
#        dataset_name  num_instances  num_features  best_node_skew  \
# 1      ada_agnostic           4562            48             NaN
# 2             colic            368            26        0.284631
# 3   credit-approval            690            15       -0.529374
# 4          credit-g           1000            20        1.368262
# 5       electricity          45312             8       -0.403566
# 6         elevators          16599            18       -0.428104
# 7           heart-h            294            13        0.126263
# 8           jasmine           2984           144       -0.244946
# 9               kc1           2109            21             NaN
# 10            nomao          34465           118        0.380720
# 11          phoneme           5404             5        0.058630
# 12            profb            672             9             NaN
# 13      qsar-biodeg           1055            41        0.148492
# 14           socmob           1156             5       -0.361372
# 0       SpeedDating           8378           120             NaN
#
#     best_node_kurt  best_node_iq_range  best_node_mean  best_node_std  \
# 1              NaN            0.000000        0.500000       0.000000
# 2        -1.173049            0.105702        0.599740       0.071867
# 3        -0.979194            0.038305        0.719909       0.040102
# 4         1.624127            0.012128        0.507649       0.012861
# 5        -0.579314            0.009547        0.732736       0.009072
# 6        -0.773457            0.014233        0.697342       0.013756
# 7        -0.931349            0.075955        0.765722       0.072736
# 8        -1.321576            0.030983        0.762767       0.022844
# 9              NaN            0.000000        0.500000       0.000000
# 10       -0.476791            0.007950        0.833644       0.007289
# 11       -0.803399            0.032952        0.740224       0.028491
# 12             NaN            0.000000        0.500000       0.000000
# 13       -1.174944            0.051162        0.728547       0.043368
# 14       -1.147356            0.058433        0.886240       0.042772
# 0              NaN            0.000000        0.500000       0.000000
#
#     best_node_max
# 1        0.500000
# 2        0.714094
# 3        0.771242
# 4        0.532143
# 5        0.746601
# 6        0.717408
# 7        0.883750
# 8        0.792864
# 9        0.500000
# 10       0.847559
# 11       0.791308
# 12       0.500000
# 13       0.802309
# 14       0.938770
# 0        0.500000

# %%
metafeatures_grouped.to_latex(
    'metafeatures_grouped.tex',
    index=False,
    float_format='%.3f',
    escape=False,
    column_format='l' + 'r' * (len(metafeatures_grouped.columns) - 1),
    label='tab:metafeatures_grouped',
    caption='Grouped metafeatures for the datasets used in the experiments.'
)

# %% [markdown]
# ## Results

# %%
results
# Out:
#      dataset_name  dataset_num_features  dataset_num_instances model_name  \
# 0    ada_agnostic                    48                   4562   CatBoost
# 1    ada_agnostic                    48                   4562   CatBoost
# 2    ada_agnostic                    48                   4562   CatBoost
# 3    ada_agnostic                    48                   4562   CatBoost
# 4    ada_agnostic                    48                   4562   CatBoost
# ..            ...                   ...                    ...        ...
# 790   SpeedDating                   120                   8378    XGBoost
# 791   SpeedDating                   120                   8378    XGBoost
# 792   SpeedDating                   120                   8378    XGBoost
# 793   SpeedDating                   120                   8378    XGBoost
# 794   SpeedDating                   120                   8378    XGBoost
#
#      train_time  val_time  test_time  train_log_loss  train_auc  \
# 0         2.803     0.002      0.000           0.262      0.943
# 1         2.067     0.000      0.000           0.247      0.954
# 2         2.655     0.003      0.000           0.300      0.920
# 3         1.747     0.000      0.002           0.253      0.950
# 4         1.347     0.002      0.002           0.278      0.933
# ..          ...       ...        ...             ...        ...
# 790       8.820     0.062      0.064           0.211      0.960
# 791       6.445     0.098      0.014           0.210      0.961
# 792       7.156     0.069      0.066           0.152      0.989
# 793      17.695     0.100      0.036           0.009      1.000
# 794       6.702     0.036      0.081           0.274      0.908
#
#      train_accuracy  train_f1  val_log_loss  val_auc  val_accuracy  val_f1  \
# 0             0.887     0.887         0.316    0.907         0.859   0.859
# 1             0.896     0.896         0.321    0.904         0.856   0.856
# 2             0.867     0.867         0.322    0.905         0.858   0.858
# 3             0.892     0.892         0.322    0.904         0.853   0.853
# 4             0.879     0.879         0.319    0.906         0.854   0.854
# ..              ...       ...           ...      ...           ...     ...
# 790           0.916     0.916         0.302    0.875         0.870   0.870
# 791           0.916     0.916         0.302    0.875         0.870   0.870
# 792           0.953     0.953         0.302    0.876         0.871   0.871
# 793           1.000     1.000         0.383    0.875         0.868   0.868
# 794           0.882     0.882         0.308    0.870         0.867   0.867
#
#      test_log_loss  test_auc  test_accuracy  test_f1
# 0            0.317     0.907          0.857    0.857
# 1            0.326     0.901          0.852    0.852
# 2            0.324     0.904          0.854    0.854
# 3            0.325     0.902          0.852    0.852
# 4            0.322     0.904          0.856    0.856
# ..             ...       ...            ...      ...
# 790          0.304     0.875          0.868    0.868
# 791          0.302     0.876          0.869    0.869
# 792          0.301     0.877          0.871    0.871
# 793          0.379     0.875          0.871    0.871
# 794          0.307     0.872          0.868    0.868
#
# [795 rows x 19 columns]

# %%
results_22_05
# Out:
#      dataset_name  dataset_num_features  dataset_num_instances model_name  \
# 0    ada_agnostic                    48                   4562   EBMModel
# 1    ada_agnostic                    48                   4562   EBMModel
# 2    ada_agnostic                    48                   4562   EBMModel
# 3    ada_agnostic                    48                   4562   EBMModel
# 4    ada_agnostic                    48                   4562   EBMModel
# ..            ...                   ...                    ...        ...
# 175   SpeedDating                   120                   8378   NAMModel
# 176   SpeedDating                   120                   8378   NAMModel
# 177   SpeedDating                   120                   8378   NAMModel
# 178   SpeedDating                   120                   8378   NAMModel
# 179   SpeedDating                   120                   8378   NAMModel
#
#      train_time  val_time  test_time  train_log_loss  train_auc  \
# 0        11.040     0.001      0.001           0.285      0.927
# 1        15.943     0.002      0.002           0.264      0.939
# 2        27.447     0.001      0.001           0.269      0.937
# 3         4.398     0.001      0.001           0.287      0.926
# 4        11.892     0.001      0.002           0.271      0.935
# ..          ...       ...        ...             ...        ...
# 175      43.489     0.057      0.059           0.333      0.848
# 176      40.852     0.209      0.220           0.337      0.843
# 177      55.375     0.048      0.046           0.329      0.852
# 178     141.860     0.555      0.490           0.324      0.858
# 179      52.853     0.676      0.347           0.337      0.844
#
#      train_accuracy  train_f1  val_log_loss  val_auc  val_accuracy  val_f1  \
# 0             0.869     0.869         0.321    0.905         0.853   0.853
# 1             0.879     0.879         0.325    0.904         0.855   0.855
# 2             0.877     0.877         0.321    0.906         0.853   0.853
# 3             0.868     0.868         0.321    0.906         0.852   0.852
# 4             0.875     0.875         0.324    0.904         0.852   0.852
# ..              ...       ...           ...      ...           ...     ...
# 175           0.852     0.852         0.340    0.839         0.850   0.850
# 176           0.849     0.849         0.341    0.838         0.846   0.846
# 177           0.852     0.852         0.337    0.842         0.847   0.847
# 178           0.855     0.855         0.332    0.848         0.852   0.852
# 179           0.848     0.848         0.341    0.839         0.846   0.846
#
#      test_log_loss  test_auc  test_accuracy  test_f1
# 0            0.321     0.906          0.853    0.853
# 1            0.325     0.904          0.853    0.853
# 2            0.320     0.906          0.855    0.855
# 3            0.322     0.906          0.851    0.851
# 4            0.325     0.904          0.851    0.851
# ..             ...       ...            ...      ...
# 175          0.339     0.840          0.848    0.848
# 176          0.341     0.838          0.850    0.850
# 177          0.337     0.842          0.850    0.850
# 178          0.332     0.847          0.851    0.851
# 179          0.341     0.839          0.849    0.849
#
# [180 rows x 19 columns]

# %%
results_tan
# Out:
#        dataset_name  dataset_num_features  dataset_num_instances model_name  \
# 0             colic                    26                    368   TANModel
# 1             colic                    26                    368   TANModel
# 2             colic                    26                    368   TANModel
# 3             colic                    26                    368   TANModel
# 4             colic                    26                    368   TANModel
# 5             colic                    26                    368   TANModel
# 6   credit-approval                    15                    690   TANModel
# 7   credit-approval                    15                    690   TANModel
# 8   credit-approval                    15                    690   TANModel
# 9   credit-approval                    15                    690   TANModel
# 10  credit-approval                    15                    690   TANModel
# 11  credit-approval                    15                    690   TANModel
# 12         credit-g                    20                   1000   TANModel
# 13         credit-g                    20                   1000   TANModel
# 14         credit-g                    20                   1000   TANModel
# 15         credit-g                    20                   1000   TANModel
# 16         credit-g                    20                   1000   TANModel
# 17         credit-g                    20                   1000   TANModel
# 18      electricity                     8                  45312   TANModel
# 19      electricity                     8                  45312   TANModel
# 20      electricity                     8                  45312   TANModel
# 21      electricity                     8                  45312   TANModel
# 22      electricity                     8                  45312   TANModel
# 23      electricity                     8                  45312   TANModel
# 24        elevators                    18                  16599   TANModel
# 25        elevators                    18                  16599   TANModel
# 26        elevators                    18                  16599   TANModel
# 27        elevators                    18                  16599   TANModel
# 28        elevators                    18                  16599   TANModel
# 29        elevators                    18                  16599   TANModel
# 30          jasmine                   144                   2984   TANModel
# 31          jasmine                   144                   2984   TANModel
# 32          jasmine                   144                   2984   TANModel
# 33          jasmine                   144                   2984   TANModel
# 34          jasmine                   144                   2984   TANModel
# 35          jasmine                   144                   2984   TANModel
# 36              kc1                    21                   2109   TANModel
# 37              kc1                    21                   2109   TANModel
# 38              kc1                    21                   2109   TANModel
# 39              kc1                    21                   2109   TANModel
# 40              kc1                    21                   2109   TANModel
# 41              kc1                    21                   2109   TANModel
# 42          phoneme                     5                   5404   TANModel
# 43          phoneme                     5                   5404   TANModel
# 44          phoneme                     5                   5404   TANModel
# 45          phoneme                     5                   5404   TANModel
# 46          phoneme                     5                   5404   TANModel
# 47          phoneme                     5                   5404   TANModel
# 48            profb                     9                    672   TANModel
# 49            profb                     9                    672   TANModel
# 50            profb                     9                    672   TANModel
# 51            profb                     9                    672   TANModel
# 52            profb                     9                    672   TANModel
# 53            profb                     9                    672   TANModel
# 54           socmob                     5                   1156   TANModel
# 55           socmob                     5                   1156   TANModel
# 56           socmob                     5                   1156   TANModel
# 57           socmob                     5                   1156   TANModel
# 58           socmob                     5                   1156   TANModel
# 59           socmob                     5                   1156   TANModel
#
#     train_time  val_time  test_time  train_log_loss  train_auc  \
# 0        0.078     0.001      0.001           0.372      0.895
# 1        0.086     0.001      0.001           0.367      0.896
# 2        0.087     0.001      0.001           0.365      0.893
# 3        0.089     0.001      0.001           0.372      0.895
# 4        0.077     0.001      0.001           0.379      0.890
# 5        0.074     0.001      0.001           0.370      0.891
# 6        0.084     0.004      0.003           0.307      0.939
# 7        0.074     0.003      0.002           0.323      0.931
# 8        0.074     0.003      0.002           0.327      0.928
# 9        0.093     0.004      0.004           0.307      0.939
# 10       0.075     0.003      0.003           0.312      0.937
# 11       0.085     0.003      0.003           0.315      0.934
# 12       0.097     0.004      0.004           0.499      0.786
# 13       0.084     0.004      0.003           0.514      0.766
# 14       0.089     0.003      0.004           0.514      0.766
# 15       0.093     0.004      0.004           0.499      0.786
# 16       0.089     0.004      0.004           0.502      0.780
# 17       0.088     0.004      0.004           0.511      0.770
# 18       1.834     0.105      0.105           0.362      0.912
# 19       1.668     0.081      0.080           0.496      0.821
# 20       1.699     0.083      0.076           0.483      0.834
# 21       1.994     0.110      0.109           0.362      0.912
# 22       1.784     0.080      0.080           0.521      0.801
# 23       1.925     0.086      0.090           0.457      0.856
# 24       1.245     0.034      0.033           0.494      0.781
# 25       1.312     0.045      0.039           0.464      0.817
# 26       1.551     0.057      0.061           0.459      0.821
# 27       1.350     0.040      0.035           0.494      0.781
# 28       1.170     0.023      0.023           0.488      0.789
# 29       1.213     0.025      0.024           0.489      0.787
# 30      64.227     0.014      0.014           0.455      0.836
# 31      59.179     0.013      0.013           0.456      0.838
# 32      58.845     0.013      0.012           0.462      0.832
# 33      65.408     0.014      0.014           0.455      0.836
# 34      62.929     0.014      0.015           0.455      0.839
# 35      61.444     0.014      0.014           0.454      0.840
# 36       0.347     0.003      0.004           0.356      0.783
# 37       0.413     0.004      0.003           0.348      0.801
# 38       0.392     0.003      0.003           0.348      0.799
# 39       0.340     0.003      0.003           0.356      0.783
# 40       0.311     0.003      0.003           0.354      0.788
# 41       0.332     0.003      0.004           0.354      0.788
# 42       0.241     0.011      0.010           0.431      0.841
# 43       0.254     0.012      0.012           0.453      0.818
# 44       0.264     0.013      0.012           0.448      0.821
# 45       0.219     0.011      0.011           0.431      0.841
# 46       0.327     0.022      0.022           0.437      0.855
# 47       0.232     0.010      0.010           0.431      0.841
# 48       0.040     0.001      0.001           0.601      0.653
# 49       0.042     0.001      0.001           0.636      0.502
# 50       0.041     0.001      0.001           0.636      0.502
# 51       0.040     0.001      0.001           0.601      0.653
# 52       0.041     0.001      0.001           0.617      0.580
# 53       0.049     0.001      0.001           0.627      0.536
# 54       0.065     0.003      0.003           0.206      0.958
# 55       0.065     0.003      0.003           0.198      0.963
# 56       0.057     0.003      0.003           0.195      0.964
# 57       0.056     0.003      0.003           0.206      0.958
# 58       0.052     0.003      0.003           0.211      0.959
# 59       0.060     0.003      0.003           0.202      0.961
#
#     train_accuracy  train_f1  val_log_loss  val_auc  val_accuracy  val_f1  \
# 0            0.857     0.857         0.407    0.888         0.856   0.856
# 1            0.857     0.857         0.392    0.883         0.851   0.851
# 2            0.848     0.848         0.406    0.870         0.837   0.837
# 3            0.857     0.857         0.407    0.888         0.856   0.856
# 4            0.857     0.857         0.409    0.875         0.856   0.856
# 5            0.853     0.853         0.394    0.883         0.853   0.853
# 6            0.877     0.877         0.345    0.931         0.868   0.868
# 7            0.866     0.866         0.381    0.917         0.861   0.861
# 8            0.864     0.864         0.344    0.925         0.862   0.862
# 9            0.877     0.877         0.345    0.931         0.868   0.868
# 10           0.874     0.874         0.344    0.929         0.861   0.861
# 11           0.865     0.865         0.345    0.927         0.862   0.862
# 12           0.754     0.754         0.554    0.747         0.744   0.744
# 13           0.743     0.743         0.554    0.732         0.718   0.718
# 14           0.743     0.743         0.554    0.732         0.718   0.718
# 15           0.754     0.754         0.554    0.747         0.744   0.744
# 16           0.751     0.751         0.565    0.737         0.724   0.724
# 17           0.746     0.746         0.562    0.730         0.717   0.717
# 18           0.824     0.824         0.460    0.880         0.799   0.799
# 19           0.764     0.764         0.499    0.819         0.763   0.763
# 20           0.766     0.766         0.489    0.830         0.764   0.764
# 21           0.824     0.824         0.460    0.880         0.799   0.799
# 22           0.751     0.751         0.522    0.799         0.750   0.750
# 23           0.780     0.780         0.485    0.842         0.773   0.773
# 24           0.783     0.783         0.495    0.781         0.783   0.783
# 25           0.786     0.786         0.466    0.815         0.788   0.788
# 26           0.790     0.790         0.460    0.820         0.790   0.790
# 27           0.783     0.783         0.495    0.781         0.783   0.783
# 28           0.779     0.779         0.488    0.789         0.779   0.779
# 29           0.779     0.779         0.490    0.786         0.777   0.777
# 30           0.784     0.784         0.466    0.828         0.781   0.781
# 31           0.791     0.791         0.469    0.828         0.785   0.785
# 32           0.788     0.788         0.470    0.828         0.787   0.787
# 33           0.784     0.784         0.466    0.828         0.781   0.781
# 34           0.791     0.791         0.470    0.828         0.789   0.789
# 35           0.791     0.791         0.466    0.832         0.791   0.791
# 36           0.845     0.845         0.357    0.784         0.845   0.845
# 37           0.851     0.851         0.352    0.799         0.852   0.852
# 38           0.854     0.854         0.352    0.798         0.853   0.853
# 39           0.845     0.845         0.357    0.784         0.845   0.845
# 40           0.845     0.845         0.358    0.786         0.845   0.845
# 41           0.845     0.845         0.358    0.786         0.845   0.845
# 42           0.771     0.771         0.438    0.836         0.770   0.770
# 43           0.760     0.760         0.455    0.817         0.757   0.757
# 44           0.764     0.764         0.451    0.816         0.762   0.762
# 45           0.771     0.771         0.438    0.836         0.770   0.770
# 46           0.783     0.783         0.456    0.847         0.778   0.778
# 47           0.771     0.771         0.438    0.836         0.770   0.770
# 48           0.667     0.667         0.614    0.638         0.656   0.656
# 49           0.667     0.667         0.641    0.497         0.667   0.667
# 50           0.667     0.667         0.641    0.497         0.667   0.667
# 51           0.667     0.667         0.614    0.638         0.656   0.656
# 52           0.672     0.672         0.633    0.558         0.665   0.665
# 53           0.669     0.669         0.641    0.516         0.661   0.661
# 54           0.920     0.920         0.214    0.956         0.926   0.926
# 55           0.927     0.927         0.227    0.955         0.926   0.926
# 56           0.922     0.922         0.214    0.960         0.922   0.922
# 57           0.920     0.920         0.214    0.956         0.926   0.926
# 58           0.916     0.916         0.222    0.953         0.918   0.918
# 59           0.924     0.924         0.213    0.958         0.926   0.926
#
#     test_log_loss  test_auc  test_accuracy  test_f1
# 0           0.416     0.877          0.845    0.845
# 1           0.407     0.869          0.842    0.842
# 2           0.392     0.864          0.843    0.843
# 3           0.416     0.877          0.845    0.845
# 4           0.429     0.868          0.851    0.851
# 5           0.404     0.870          0.845    0.845
# 6           0.348     0.927          0.857    0.857
# 7           0.360     0.917          0.851    0.851
# 8           0.356     0.916          0.851    0.851
# 9           0.348     0.927          0.857    0.857
# 10          0.337     0.928          0.867    0.867
# 11          0.353     0.918          0.848    0.848
# 12          0.555     0.735          0.741    0.741
# 13          0.552     0.731          0.724    0.724
# 14          0.552     0.731          0.724    0.724
# 15          0.555     0.735          0.741    0.741
# 16          0.565     0.725          0.722    0.722
# 17          0.556     0.727          0.726    0.726
# 18          0.461     0.880          0.800    0.800
# 19          0.498     0.820          0.764    0.764
# 20          0.489     0.830          0.763    0.763
# 21          0.461     0.880          0.800    0.800
# 22          0.524     0.798          0.751    0.751
# 23          0.484     0.842          0.772    0.772
# 24          0.495     0.781          0.783    0.783
# 25          0.466     0.815          0.785    0.785
# 26          0.460     0.820          0.789    0.789
# 27          0.495     0.781          0.783    0.783
# 28          0.488     0.789          0.779    0.779
# 29          0.491     0.784          0.778    0.778
# 30          0.473     0.826          0.779    0.779
# 31          0.482     0.824          0.783    0.783
# 32          0.478     0.826          0.783    0.783
# 33          0.473     0.826          0.779    0.779
# 34          0.476     0.827          0.784    0.784
# 35          0.476     0.827          0.785    0.785
# 36          0.358     0.781          0.845    0.845
# 37          0.352     0.796          0.851    0.851
# 38          0.353     0.794          0.853    0.853
# 39          0.358     0.781          0.845    0.845
# 40          0.358     0.784          0.845    0.845
# 41          0.358     0.784          0.845    0.845
# 42          0.436     0.837          0.771    0.771
# 43          0.455     0.818          0.755    0.755
# 44          0.450     0.818          0.762    0.762
# 45          0.436     0.837          0.771    0.771
# 46          0.458     0.845          0.775    0.775
# 47          0.436     0.837          0.771    0.771
# 48          0.611     0.640          0.653    0.653
# 49          0.639     0.498          0.667    0.667
# 50          0.639     0.498          0.667    0.667
# 51          0.611     0.640          0.653    0.653
# 52          0.634     0.547          0.659    0.659
# 53          0.635     0.524          0.667    0.667
# 54          0.217     0.956          0.920    0.920
# 55          0.226     0.958          0.925    0.925
# 56          0.221     0.959          0.923    0.923
# 57          0.217     0.956          0.920    0.920
# 58          0.221     0.955          0.918    0.918
# 59          0.215     0.957          0.925    0.925

# %%
results = results[~results['model_name'].isin(['NAMModel', 'EBMModel'])]

# %%
results = pd.concat([results, results_22_05, results_tan], axis=0)

# %% [markdown]
# ### Grouping by model

# %%
results.groupby(['model_name']).size()
# Out:
# model_name
# CatBoost                   90
# EBMModel                   90
# GaussianNaiveBayesModel    90
# LDAModel                   77
# LightGBM                   90
# LinearModelInterpret       90
# NAMModel                   90
# RandomForest               90
# TANModel                   60
# XGBoost                    90
# dtype: int64

# %%
results
# Out:
#     dataset_name  dataset_num_features  dataset_num_instances model_name  \
# 0   ada_agnostic                    48                   4562   CatBoost
# 1   ada_agnostic                    48                   4562   CatBoost
# 2   ada_agnostic                    48                   4562   CatBoost
# 3   ada_agnostic                    48                   4562   CatBoost
# 4   ada_agnostic                    48                   4562   CatBoost
# ..           ...                   ...                    ...        ...
# 55        socmob                     5                   1156   TANModel
# 56        socmob                     5                   1156   TANModel
# 57        socmob                     5                   1156   TANModel
# 58        socmob                     5                   1156   TANModel
# 59        socmob                     5                   1156   TANModel
#
#     train_time  val_time  test_time  train_log_loss  train_auc  \
# 0        2.803     0.002      0.000           0.262      0.943
# 1        2.067     0.000      0.000           0.247      0.954
# 2        2.655     0.003      0.000           0.300      0.920
# 3        1.747     0.000      0.002           0.253      0.950
# 4        1.347     0.002      0.002           0.278      0.933
# ..         ...       ...        ...             ...        ...
# 55       0.065     0.003      0.003           0.198      0.963
# 56       0.057     0.003      0.003           0.195      0.964
# 57       0.056     0.003      0.003           0.206      0.958
# 58       0.052     0.003      0.003           0.211      0.959
# 59       0.060     0.003      0.003           0.202      0.961
#
#     train_accuracy  train_f1  val_log_loss  val_auc  val_accuracy  val_f1  \
# 0            0.887     0.887         0.316    0.907         0.859   0.859
# 1            0.896     0.896         0.321    0.904         0.856   0.856
# 2            0.867     0.867         0.322    0.905         0.858   0.858
# 3            0.892     0.892         0.322    0.904         0.853   0.853
# 4            0.879     0.879         0.319    0.906         0.854   0.854
# ..             ...       ...           ...      ...           ...     ...
# 55           0.927     0.927         0.227    0.955         0.926   0.926
# 56           0.922     0.922         0.214    0.960         0.922   0.922
# 57           0.920     0.920         0.214    0.956         0.926   0.926
# 58           0.916     0.916         0.222    0.953         0.918   0.918
# 59           0.924     0.924         0.213    0.958         0.926   0.926
#
#     test_log_loss  test_auc  test_accuracy  test_f1
# 0           0.317     0.907          0.857    0.857
# 1           0.326     0.901          0.852    0.852
# 2           0.324     0.904          0.854    0.854
# 3           0.325     0.902          0.852    0.852
# 4           0.322     0.904          0.856    0.856
# ..            ...       ...            ...      ...
# 55          0.226     0.958          0.925    0.925
# 56          0.221     0.959          0.923    0.923
# 57          0.217     0.956          0.920    0.920
# 58          0.221     0.955          0.918    0.918
# 59          0.215     0.957          0.925    0.925
#
# [857 rows x 19 columns]

# %%
results_grouped = results.groupby('model_name').agg(
    {'train_time': ['mean'],
     'test_time': ['mean'],
     'test_accuracy': ['mean'],
     'test_log_loss': ['mean'],
    }
).round(3)

# %%
results_grouped.columns = ['_'.join(col).strip() for col in results_grouped.columns.values]
results_grouped.reset_index()
# Out:
#                 model_name  train_time_mean  test_time_mean  \
# 0                 CatBoost           29.598           0.011
# 1                 EBMModel           36.846           0.003
# 2  GaussianNaiveBayesModel            0.074           0.004
# 3                 LDAModel            0.406           0.004
# 4                 LightGBM            2.271           0.046
# 5     LinearModelInterpret            1.506           0.004
# 6                 NAMModel           30.562           0.084
# 7             RandomForest            0.436           0.016
# 8                 TANModel            6.610           0.017
# 9                  XGBoost           12.072           0.034
#
#    test_accuracy_mean  test_log_loss_mean
# 0               0.856               0.330
# 1               0.850               0.338
# 2               0.751               2.152
# 3               0.816               0.415
# 4               0.833               0.642
# 5               0.799               0.445
# 6               0.795               0.451
# 7               0.827               0.403
# 8               0.797               0.441
# 9               0.854               0.340

# %%
results_grouped['test_accuracy_rank'] = results_grouped['test_accuracy_mean'].rank(ascending=False, method='min')
results_grouped['test_log_loss_rank'] = results_grouped['test_log_loss_mean'].rank(ascending=True, method='min')
results_grouped['train_time_rank'] = results_grouped['train_time_mean'].rank(ascending=True, method='min')
results_grouped['test_time_rank'] = results_grouped['test_time_mean'].rank(ascending=True, method='min')

# %%
results_grouped = results_grouped.reset_index()

# %%
results_grouped[['model_name', 'test_accuracy_mean', 'test_log_loss_mean', 
                 'test_accuracy_rank', 'test_log_loss_rank']]
# Out:
#                 model_name  test_accuracy_mean  test_log_loss_mean  \
# 0                 CatBoost               0.856               0.330
# 1                 EBMModel               0.850               0.338
# 2  GaussianNaiveBayesModel               0.751               2.152
# 3                 LDAModel               0.816               0.415
# 4                 LightGBM               0.833               0.642
# 5     LinearModelInterpret               0.799               0.445
# 6                 NAMModel               0.795               0.451
# 7             RandomForest               0.827               0.403
# 8                 TANModel               0.797               0.441
# 9                  XGBoost               0.854               0.340
#
#    test_accuracy_rank  test_log_loss_rank
# 0                 1.0                 1.0
# 1                 3.0                 2.0
# 2                10.0                10.0
# 3                 6.0                 5.0
# 4                 4.0                 9.0
# 5                 7.0                 7.0
# 6                 9.0                 8.0
# 7                 5.0                 4.0
# 8                 8.0                 6.0
# 9                 2.0                 3.0

# %%
results_grouped[['model_name', 'train_time_mean', 'test_time_mean', 'train_time_rank', 'test_time_rank']]
# Out:
#                 model_name  train_time_mean  test_time_mean  train_time_rank  \
# 0                 CatBoost           29.598           0.011              8.0
# 1                 EBMModel           36.846           0.003             10.0
# 2  GaussianNaiveBayesModel            0.074           0.004              1.0
# 3                 LDAModel            0.406           0.004              2.0
# 4                 LightGBM            2.271           0.046              5.0
# 5     LinearModelInterpret            1.506           0.004              4.0
# 6                 NAMModel           30.562           0.084              9.0
# 7             RandomForest            0.436           0.016              3.0
# 8                 TANModel            6.610           0.017              6.0
# 9                  XGBoost           12.072           0.034              7.0
#
#    test_time_rank
# 0             5.0
# 1             1.0
# 2             2.0
# 3             2.0
# 4             9.0
# 5             2.0
# 6            10.0
# 7             6.0
# 8             7.0
# 9             8.0

# %% [markdown]
# ### Grouping by dataset

# %%
results = results.reset_index(drop=True)

# %%
# Obtener índices de la fila con mayor test_accuracy por grupo
idx = results.groupby(['model_name', 'dataset_name'])['test_accuracy'].idxmax()

# Seleccionar esas filas
best_results = results.loc[idx]
best_results = best_results.round(5).reset_index(drop=True)

# %%
best_results.loc[best_results['dataset_name'] == 'kc1', ['dataset_name', 'model_name', 'test_accuracy']]
# Out:
#     dataset_name               model_name  test_accuracy
# 9            kc1                 CatBoost          0.859
# 24           kc1                 EBMModel          0.859
# 39           kc1  GaussianNaiveBayesModel          0.831
# 54           kc1                 LDAModel          0.858
# 69           kc1                 LightGBM          0.859
# 84           kc1     LinearModelInterpret          0.856
# 99           kc1                 NAMModel          0.851
# 114          kc1             RandomForest          0.859
# 126          kc1                 TANModel          0.853
# 139          kc1                  XGBoost          0.859

# %%
def get_best_model_and_accuracy_old(dataset_name):
    dataset = best_results[best_results['dataset_name'] == dataset_name]
    try:
        best_model = dataset.loc[dataset['test_accuracy'].idxmax()]['model_name']
        second_best_model = dataset.loc[dataset['test_accuracy'].nlargest(2).idxmin()]['model_name']
        third_best_model = dataset.loc[dataset['test_accuracy'].nlargest(3).idxmin()]['model_name']
        best_accuracy = dataset['test_accuracy'].max()
        second_best_accuracy = dataset['test_accuracy'].nlargest(2).min()
        third_best_accuracy = dataset['test_accuracy'].nlargest(3).min()
        return best_model, best_accuracy, second_best_model, second_best_accuracy, third_best_model, third_best_accuracy
    except Exception as e:
        return None, None, None, None, None, None

def get_best_model_and_accuracy(dataset_name):
    dataset = best_results[best_results['dataset_name'] == dataset_name]
    try:
        # Ordenamos por test_accuracy descendente y eliminamos duplicados por model_name
        top_unique_models = dataset.sort_values(by='test_accuracy', ascending=False).drop_duplicates(subset='model_name')
        
        # Seleccionamos los tres mejores
        top3 = top_unique_models.head(3)
        
        # Extraemos los nombres y accuracies
        best_model = top3.iloc[0]['model_name']
        best_accuracy = top3.iloc[0]['test_accuracy']
        
        second_best_model = top3.iloc[1]['model_name']
        second_best_accuracy = top3.iloc[1]['test_accuracy']
        
        third_best_model = top3.iloc[2]['model_name']
        third_best_accuracy = top3.iloc[2]['test_accuracy']
        
        return best_model, best_accuracy, second_best_model, second_best_accuracy, third_best_model, third_best_accuracy
    except Exception as e:
        return None, None, None, None, None, None

# %%
metafeatures_grouped[['best_model', 'best_accuracy', 'second_best_model', 'second_best_accuracy', 'third_best_model', 'third_best_accuracy']] = metafeatures_grouped['dataset_name'].apply(
    lambda x: pd.Series(get_best_model_and_accuracy(x))
)

# %%
metafeatures_grouped[['dataset_name', 'num_instances', 'num_features', 
                      'best_model', 'best_accuracy',
                      'second_best_model', 'second_best_accuracy',
                      'third_best_model', 'third_best_accuracy']]
# Out:
#        dataset_name  num_instances  num_features best_model  best_accuracy  \
# 1      ada_agnostic           4562            48    XGBoost          0.858
# 2             colic            368            26    XGBoost          0.875
# 3   credit-approval            690            15   EBMModel          0.880
# 4          credit-g           1000            20    XGBoost          0.769
# 5       electricity          45312             8    XGBoost          0.944
# 6         elevators          16599            18   EBMModel          0.905
# 7           heart-h            294            13   CatBoost          0.837
# 8           jasmine           2984           144   CatBoost          0.817
# 9               kc1           2109            21   CatBoost          0.859
# 10            nomao          34465           118   LightGBM          0.974
# 11          phoneme           5404             5   LightGBM          0.910
# 12            profb            672             9   CatBoost          0.751
# 13      qsar-biodeg           1055            41   EBMModel          0.882
# 14           socmob           1156             5   EBMModel          0.952
# 0       SpeedDating           8378           120   LightGBM          0.871
#
#        second_best_model  second_best_accuracy third_best_model  \
# 1               CatBoost                 0.857         EBMModel
# 2               CatBoost                 0.867     RandomForest
# 3               CatBoost                 0.877     RandomForest
# 4               EBMModel                 0.760         CatBoost
# 5               LightGBM                 0.914         CatBoost
# 6   LinearModelInterpret                 0.899         CatBoost
# 7               EBMModel                 0.830     RandomForest
# 8                XGBoost                 0.815         LightGBM
# 9               EBMModel                 0.859         LightGBM
# 10               XGBoost                 0.973         CatBoost
# 11              CatBoost                 0.907          XGBoost
# 12              LightGBM                 0.713         EBMModel
# 13              LightGBM                 0.872         CatBoost
# 14               XGBoost                 0.948     RandomForest
# 0                XGBoost                 0.871         EBMModel
#
#     third_best_accuracy
# 1                 0.855
# 2                 0.858
# 3                 0.871
# 4                 0.746
# 5                 0.905
# 6                 0.898
# 7                 0.827
# 8                 0.812
# 9                 0.859
# 10                0.972
# 11                0.905
# 12                0.686
# 13                0.869
# 14                0.944
# 0                 0.870

# %% [markdown]
# ### Gráfico Accuracy vs Time

# %%
import plotly.express as px
import pandas as pd
import plotly

# Datos
data = {
    "model": [
        "CatBoost", "EBM", "GaussianNB", "LDA", "LightGBM",
        "LogisticReg", "NAM", "RandomForest", "TAN", "XGBoost"
    ],
    "accuracy_rank": [1, 3, 10, 6, 4, 7, 9, 5, 8, 2],
    "train_time_rank": [8, 10, 1, 2, 5, 4, 9, 3, 6, 7]
}

df = pd.DataFrame(data)

# Añadir columna de interpretabilidad
interpretable_models = {"EBM", "GaussianNB", "LDA", "LogisticReg", "NAM", "TAN"}
df["Interpretable"] = df["model"].apply(lambda x: "Sí" if x in interpretable_models else "No")

# Gráfico
fig = px.scatter(
    df,
    x="train_time_rank",
    y="accuracy_rank",
    text="model",
    color="Interpretable",
    color_discrete_map={"Sí": "green", "No": "red"},
    labels={
        "train_time_rank": "Ranking de Tiempo de Entrenamiento",
        "accuracy_rank": "Ranking de Accuracy",
        "Interpretable": "¿Interpretable?"
    }
)

# Invertir ejes (porque rank 1 es mejor que rank 10)
fig.update_layout(
    xaxis=dict(autorange="reversed"),
    yaxis=dict(autorange="reversed"),
    template="seaborn",
    width=700,
    height=600,
    font=dict(color="#000000", size=18),
    xaxis_title_font=dict(size=20),
    yaxis_title_font=dict(size=20),
    legend_title_font=dict(size=16),
)

fig.update_traces(
    textposition='top center',
    cliponaxis=False,
)

fig.show()
# Out:
# c:\Users\javip\anaconda3\envs\testing-tabzilla\lib\site-packages\plotly\express\_core.py:1992: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
plotly.offline.plot(fig, image_filename="plot.svg", image='svg')
# Out:
# 'temp-plot.html'

# %%
# Guardar el gráfico como archivo SVG
fig.write_image("trade_off_accuracy_vs_train_time.png", format="png")
